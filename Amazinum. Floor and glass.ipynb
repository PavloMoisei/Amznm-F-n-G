# %% [markdown]
# #### Amazinum. Task to minimize max drops. Moisei

# %% [markdown]
# - We need a strategy that tries to make solutions to all possible answers the same depth (same number of drops). The way to reduce the worst case is to attempt to make all cases take the same number of drops.
# - If the solution lays somewhere in a floor low down, then we have extra-headroom when we need to step by singles, but, as we get higher up the building, we’ve already used drop chances to get there, so there we have less drops left when we have to switch to going floor-by-floor.
# - Imagine we drop our first glass from floor n, if it breaks, we can step through the previous (n-1) floors one-by-one. If it doesn’t break, rather than jumping up another n floors, instead we should step up just (n-1) floors (because we have one less drop available if we have to switch to one-by-one floors), so the next floor we should try is floor n + (n-1). Similarly, if this drop does not break, we next need to jump up to floor n + (n-1) + (n-2), then floor n + (n-1) + (n-2) + (n-3)…
# - We keep reducing the step by one each time we jump up, until that step-up is just one floor, and get the following equation for a f floor building: n + (n-1) + (n-2) + (n-3) + (n-4) + … + 1 >= f.
# - This summation, as many will recognize, is the formula for triangular numbers (which kind of makes sense, since we’re reducing the step by one each drop we make) and can be simplified to: n (n+1) / 2 >= f.

# %% [markdown]
# ### В мене получився код з двома результатами. При цьому я вибрав 8 стаканів та 2000 поверхів. Перший результат показує число максимальних кидків, а другий показує кроки випробувань, при якому максимальна кількість кидків виходить ще нижча.
# #### 1. Я хотів показати кінцевий результат, а також кроки алгоритму. Вийшло що при показі алгоритму, кількість максимальних кидків стаканів ще менша. З нашими даними це число 12 та якщо дивитись на візуалізацію в вигляді дерева, то число 5.
# #### 2. В результаті кидання 8-ми стаканів з 2000 поверхів, ми починаємо з 12го поверху. І далі піднімаємось ще 12 разів аж до 2000 поверху.
# #### 3. При decision tree, ми починаємо з 1816го поверху, потім 1944го, 1976го і т. д.

# %%
Max = 10000
  
def glassDrop(f, n):
    # A 2D table where entry glassFloor[i][j] will represent minimum
    # number of trials needed for i glasses and j floors.
    glassFloor = [[0 for x in range(f + 1)] for x in range(n + 1)]
  
    # We need one trial for one floor and 0 trials for 0 floors
    for i in range(1, n + 1):
        glassFloor[i][1] = 1
        glassFloor[i][0] = 0
  
    # We always need j trials for one glass and j floors.
    for j in range(1, f + 1):
        glassFloor[1][j] = j
  
    # Fill rest of the entries in table using optimal substructure
    # property
    for i in range(2, n + 1):
        for j in range(2, f + 1):
            glassFloor[i][j] = Max
            for x in range(1, j + 1):
                res = 1 + max(glassFloor[i-1][x-1], glassFloor[i][j-x])
                if res < glassFloor[i][j]:
                    glassFloor[i][j] = res
  
    # glassFloor[n][f] holds the result
    return glassFloor[n][f]

def optimal_solution(f, n):
    
    dp = []

    # With no drops, we can do no floors
    dp.append([0 for x in range(n+1)])

    # With one drop and any glasses, we can do 1 floor
    one_drop = [1 for _ in range(n+1)]
    one_drop[0] = 0 # Except no glasses is still no floors
    dp.append(one_drop)

    # Keep adding drops until we have our answer
    # Array element -1 is shorthand for the end of the array.
    while dp[-1][n] < f:
        # 0 floors for 0 glasses.  1 more for one glass
        next_drop = [0, dp[-1][1] + 1]
        for i in range(2, n+1): # Python for 2..glasses
            # The best we can do is drop at floor dp[-1][i-1].
            # If the glass breaks, we can find the answer using that solution.
            # If the glass holds, we can find another dp[-1][i] floors.
            next_drop.append(dp[-1][i] + dp[-1][i-1])
        dp.append(next_drop)

    return dp

# This turns that optimal solution into a decision tree.    
def dp_to_decision_tree(dp, floors, start_floor=None, glasses=None, drops=None):
    # Figure out defaults if needed.
    if start_floor is None:
        start_floor = 0
    if drops is None:
        drops = len(dp) - 1
    if glasses is None:
        glasses = len(dp[0]) - 1

    if floors == start_floor:
        return start_floor
    elif dp[drops][glasses] < floors - start_floor:
        return None

    while floors - start_floor < dp[drops-1][glasses]:
        drops -= 1

    drop_at = start_floor + dp[drops-1][glasses-1]
    if glasses == 1:
        drop_at = start_floor + 1
    if floors < drop_at:
        drop_at = floors
    return [
        drop_at,
        dp_to_decision_tree(dp,  floors,     drop_at,   glasses, drops-1),
        dp_to_decision_tree(dp, drop_at-1, start_floor, glasses-1, drops-1),
        {'glasses': glasses, 'floor_range': (start_floor, floors)}
        ]

# This prints the decision_tree in a human readable format.
def print_decision_tree(tree, indent="", label="start"):
    if tree is None:
        print(f"{indent}{label}: ?")
    elif isinstance(tree, int):
        print(f"{indent}{label}: {tree} found")
    else:
        print(f"{indent}{label}: {tree[0]} {tree[3]}")
        print_decision_tree(tree[1], indent + "    ", label="didn't broke")
        print_decision_tree(tree[2], indent + "    ", label="broke")

# And this calls the previous functions.
def print_optimal_decisions(f, n):
    print_decision_tree(
        dp_to_decision_tree(
            optimal_solution(f, n), f))
    
     # Driver code
if __name__ == "__main__":
    n = 8
    f = 2000
    print("Minimum number of trials in worst case with " + str(n) + " glasses and "
        + str(f) + " floors is " + str(glassDrop(f, n)) + '\n','\nSteps of trials:\n')

    print_optimal_decisions(f, n)
# Out:
# Minimum number of trials in worst case with 8 glasses and 2000 floors is 12
#
# Steps of trials:
#
# start: 1816 {'glasses': 8, 'floor_range': (0, 2000)}
#     didn't broke: 1944 {'glasses': 8, 'floor_range': (1816, 2000)}
#         didn't broke: 1976 {'glasses': 8, 'floor_range': (1944, 2000)}
#             didn't broke: 1992 {'glasses': 8, 'floor_range': (1976, 2000)}
#                 didn't broke: 2000 {'glasses': 8, 'floor_range': (1992, 2000)}
#                     didn't broke: 2000 found
#                     broke: 1996 {'glasses': 7, 'floor_range': (1992, 1999)}
#                         didn't broke: 1998 {'glasses': 7, 'floor_range': (1996, 1999)}
#                             didn't broke: 1999 {'glasses': 7, 'floor_range': (1998, 1999)}
#                                 didn't broke: 1999 found
#                                 broke: 1998 found
#                             broke: 1997 {'glasses': 6, 'floor_range': (1996, 1997)}
#                                 didn't broke: 1997 found
#                                 broke: 1996 found
#                         broke: 1994 {'glasses': 6, 'floor_range': (1992, 1995)}
#                             didn't broke: 1995 {'glasses': 6, 'floor_range': (1994, 1995)}
#                                 didn't broke: 1995 found
#                                 broke: 1994 found
#                             broke: 1993 {'glasses': 5, 'floor_range': (1992, 1993)}
#                                 didn't broke: 1993 found
#                                 broke: 1992 found
#                 broke: 1984 {'glasses': 7, 'floor_range': (1976, 1991)}
#                     didn't broke: 1988 {'glasses': 7, 'floor_range': (1984, 1991)}
#                         didn't broke: 1990 {'glasses': 7, 'floor_range': (1988, 1991)}
#                             didn't broke: 1991 {'glasses': 7, 'floor_range': (1990, 1991)}
#                                 didn't broke: 1991 found
#                                 broke: 1990 found
#                             broke: 1989 {'glasses': 6, 'floor_range': (1988, 1989)}
#                                 didn't broke: 1989 found
#                                 broke: 1988 found
#                         broke: 1986 {'glasses': 6, 'floor_range': (1984, 1987)}
#                             didn't broke: 1987 {'glasses': 6, 'floor_range': (1986, 1987)}
#                                 didn't broke: 1987 found
#                                 broke: 1986 found
#                             broke: 1985 {'glasses': 5, 'floor_range': (1984, 1985)}
#                                 didn't broke: 1985 found
#                                 broke: 1984 found
#                     broke: 1980 {'glasses': 6, 'floor_range': (1976, 1983)}
#                         didn't broke: 1982 {'glasses': 6, 'floor_range': (1980, 1983)}
#                             didn't broke: 1983 {'glasses': 6, 'floor_range': (1982, 1983)}
#                                 didn't broke: 1983 found
#                                 broke: 1982 found
#                             broke: 1981 {'glasses': 5, 'floor_range': (1980, 1981)}
#                                 didn't broke: 1981 found
#                                 broke: 1980 found
#                         broke: 1978 {'glasses': 5, 'floor_range': (1976, 1979)}
#                             didn't broke: 1979 {'glasses': 5, 'floor_range': (1978, 1979)}
#                                 didn't broke: 1979 found
#                                 broke: 1978 found
#                             broke: 1977 {'glasses': 4, 'floor_range': (1976, 1977)}
#                                 didn't broke: 1977 found
#                                 broke: 1976 found
#             broke: 1960 {'glasses': 7, 'floor_range': (1944, 1975)}
#                 didn't broke: 1968 {'glasses': 7, 'floor_range': (1960, 1975)}
#                     didn't broke: 1972 {'glasses': 7, 'floor_range': (1968, 1975)}
#                         didn't broke: 1974 {'glasses': 7, 'floor_range': (1972, 1975)}
#                             didn't broke: 1975 {'glasses': 7, 'floor_range': (1974, 1975)}
#                                 didn't broke: 1975 found
#                                 broke: 1974 found
#                             broke: 1973 {'glasses': 6, 'floor_range': (1972, 1973)}
#                                 didn't broke: 1973 found
#                                 broke: 1972 found
#                         broke: 1970 {'glasses': 6, 'floor_range': (1968, 1971)}
#                             didn't broke: 1971 {'glasses': 6, 'floor_range': (1970, 1971)}
#                                 didn't broke: 1971 found
#                                 broke: 1970 found
#                             broke: 1969 {'glasses': 5, 'floor_range': (1968, 1969)}
#                                 didn't broke: 1969 found
#                                 broke: 1968 found
#                     broke: 1964 {'glasses': 6, 'floor_range': (1960, 1967)}
#                         didn't broke: 1966 {'glasses': 6, 'floor_range': (1964, 1967)}
#                             didn't broke: 1967 {'glasses': 6, 'floor_range': (1966, 1967)}
#                                 didn't broke: 1967 found
#                                 broke: 1966 found
#                             broke: 1965 {'glasses': 5, 'floor_range': (1964, 1965)}
#                                 didn't broke: 1965 found
#                                 broke: 1964 found
#                         broke: 1962 {'glasses': 5, 'floor_range': (1960, 1963)}
#                             didn't broke: 1963 {'glasses': 5, 'floor_range': (1962, 1963)}
#                                 didn't broke: 1963 found
#                                 broke: 1962 found
#                             broke: 1961 {'glasses': 4, 'floor_range': (1960, 1961)}
#                                 didn't broke: 1961 found
#                                 broke: 1960 found
#                 broke: 1952 {'glasses': 6, 'floor_range': (1944, 1959)}
#                     didn't broke: 1956 {'glasses': 6, 'floor_range': (1952, 1959)}
#                         didn't broke: 1958 {'glasses': 6, 'floor_range': (1956, 1959)}
#                             didn't broke: 1959 {'glasses': 6, 'floor_range': (1958, 1959)}
#                                 didn't broke: 1959 found
#                                 broke: 1958 found
#                             broke: 1957 {'glasses': 5, 'floor_range': (1956, 1957)}
#                                 didn't broke: 1957 found
#                                 broke: 1956 found
#                         broke: 1954 {'glasses': 5, 'floor_range': (1952, 1955)}
#                             didn't broke: 1955 {'glasses': 5, 'floor_range': (1954, 1955)}
#                                 didn't broke: 1955 found
#                                 broke: 1954 found
#                             broke: 1953 {'glasses': 4, 'floor_range': (1952, 1953)}
#                                 didn't broke: 1953 found
#                                 broke: 1952 found
#                     broke: 1948 {'glasses': 5, 'floor_range': (1944, 1951)}
#                         didn't broke: 1950 {'glasses': 5, 'floor_range': (1948, 1951)}
#                             didn't broke: 1951 {'glasses': 5, 'floor_range': (1950, 1951)}
#                                 didn't broke: 1951 found
#                                 broke: 1950 found
#                             broke: 1949 {'glasses': 4, 'floor_range': (1948, 1949)}
#                                 didn't broke: 1949 found
#                                 broke: 1948 found
#                         broke: 1946 {'glasses': 4, 'floor_range': (1944, 1947)}
#                             didn't broke: 1947 {'glasses': 4, 'floor_range': (1946, 1947)}
#                                 didn't broke: 1947 found
#                                 broke: 1946 found
#                             broke: 1945 {'glasses': 3, 'floor_range': (1944, 1945)}
#                                 didn't broke: 1945 found
#                                 broke: 1944 found
#         broke: 1880 {'glasses': 7, 'floor_range': (1816, 1943)}
#             didn't broke: 1912 {'glasses': 7, 'floor_range': (1880, 1943)}
#                 didn't broke: 1928 {'glasses': 7, 'floor_range': (1912, 1943)}
#                     didn't broke: 1936 {'glasses': 7, 'floor_range': (1928, 1943)}
#                         didn't broke: 1940 {'glasses': 7, 'floor_range': (1936, 1943)}
#                             didn't broke: 1942 {'glasses': 7, 'floor_range': (1940, 1943)}
#                                 didn't broke: 1943 {'glasses': 7, 'floor_range': (1942, 1943)}
#                                     didn't broke: 1943 found
#                                     broke: 1942 found
#                                 broke: 1941 {'glasses': 6, 'floor_range': (1940, 1941)}
#                                     didn't broke: 1941 found
#                                     broke: 1940 found
#                             broke: 1938 {'glasses': 6, 'floor_range': (1936, 1939)}
#                                 didn't broke: 1939 {'glasses': 6, 'floor_range': (1938, 1939)}
#                                     didn't broke: 1939 found
#                                     broke: 1938 found
#                                 broke: 1937 {'glasses': 5, 'floor_range': (1936, 1937)}
#                                     didn't broke: 1937 found
#                                     broke: 1936 found
#                         broke: 1932 {'glasses': 6, 'floor_range': (1928, 1935)}
#                             didn't broke: 1934 {'glasses': 6, 'floor_range': (1932, 1935)}
#                                 didn't broke: 1935 {'glasses': 6, 'floor_range': (1934, 1935)}
#                                     didn't broke: 1935 found
#                                     broke: 1934 found
#                                 broke: 1933 {'glasses': 5, 'floor_range': (1932, 1933)}
#                                     didn't broke: 1933 found
#                                     broke: 1932 found
#                             broke: 1930 {'glasses': 5, 'floor_range': (1928, 1931)}
#                                 didn't broke: 1931 {'glasses': 5, 'floor_range': (1930, 1931)}
#                                     didn't broke: 1931 found
#                                     broke: 1930 found
#                                 broke: 1929 {'glasses': 4, 'floor_range': (1928, 1929)}
#                                     didn't broke: 1929 found
#                                     broke: 1928 found
#                     broke: 1920 {'glasses': 6, 'floor_range': (1912, 1927)}
#                         didn't broke: 1924 {'glasses': 6, 'floor_range': (1920, 1927)}
#                             didn't broke: 1926 {'glasses': 6, 'floor_range': (1924, 1927)}
#                                 didn't broke: 1927 {'glasses': 6, 'floor_range': (1926, 1927)}
#                                     didn't broke: 1927 found
#                                     broke: 1926 found
#                                 broke: 1925 {'glasses': 5, 'floor_range': (1924, 1925)}
#                                     didn't broke: 1925 found
#                                     broke: 1924 found
#                             broke: 1922 {'glasses': 5, 'floor_range': (1920, 1923)}
#                                 didn't broke: 1923 {'glasses': 5, 'floor_range': (1922, 1923)}
#                                     didn't broke: 1923 found
#                                     broke: 1922 found
#                                 broke: 1921 {'glasses': 4, 'floor_range': (1920, 1921)}
#                                     didn't broke: 1921 found
#                                     broke: 1920 found
#                         broke: 1916 {'glasses': 5, 'floor_range': (1912, 1919)}
#                             didn't broke: 1918 {'glasses': 5, 'floor_range': (1916, 1919)}
#                                 didn't broke: 1919 {'glasses': 5, 'floor_range': (1918, 1919)}
#                                     didn't broke: 1919 found
#                                     broke: 1918 found
#                                 broke: 1917 {'glasses': 4, 'floor_range': (1916, 1917)}
#                                     didn't broke: 1917 found
#                                     broke: 1916 found
#                             broke: 1914 {'glasses': 4, 'floor_range': (1912, 1915)}
#                                 didn't broke: 1915 {'glasses': 4, 'floor_range': (1914, 1915)}
#                                     didn't broke: 1915 found
#                                     broke: 1914 found
#                                 broke: 1913 {'glasses': 3, 'floor_range': (1912, 1913)}
#                                     didn't broke: 1913 found
#                                     broke: 1912 found
#                 broke: 1896 {'glasses': 6, 'floor_range': (1880, 1911)}
#                     didn't broke: 1904 {'glasses': 6, 'floor_range': (1896, 1911)}
#                         didn't broke: 1908 {'glasses': 6, 'floor_range': (1904, 1911)}
#                             didn't broke: 1910 {'glasses': 6, 'floor_range': (1908, 1911)}
#                                 didn't broke: 1911 {'glasses': 6, 'floor_range': (1910, 1911)}
#                                     didn't broke: 1911 found
#                                     broke: 1910 found
#                                 broke: 1909 {'glasses': 5, 'floor_range': (1908, 1909)}
#                                     didn't broke: 1909 found
#                                     broke: 1908 found
#                             broke: 1906 {'glasses': 5, 'floor_range': (1904, 1907)}
#                                 didn't broke: 1907 {'glasses': 5, 'floor_range': (1906, 1907)}
#                                     didn't broke: 1907 found
#                                     broke: 1906 found
#                                 broke: 1905 {'glasses': 4, 'floor_range': (1904, 1905)}
#                                     didn't broke: 1905 found
#                                     broke: 1904 found
#                         broke: 1900 {'glasses': 5, 'floor_range': (1896, 1903)}
#                             didn't broke: 1902 {'glasses': 5, 'floor_range': (1900, 1903)}
#                                 didn't broke: 1903 {'glasses': 5, 'floor_range': (1902, 1903)}
#                                     didn't broke: 1903 found
#                                     broke: 1902 found
#                                 broke: 1901 {'glasses': 4, 'floor_range': (1900, 1901)}
#                                     didn't broke: 1901 found
#                                     broke: 1900 found
#                             broke: 1898 {'glasses': 4, 'floor_range': (1896, 1899)}
#                                 didn't broke: 1899 {'glasses': 4, 'floor_range': (1898, 1899)}
#                                     didn't broke: 1899 found
#                                     broke: 1898 found
#                                 broke: 1897 {'glasses': 3, 'floor_range': (1896, 1897)}
#                                     didn't broke: 1897 found
#                                     broke: 1896 found
#                     broke: 1888 {'glasses': 5, 'floor_range': (1880, 1895)}
#                         didn't broke: 1892 {'glasses': 5, 'floor_range': (1888, 1895)}
#                             didn't broke: 1894 {'glasses': 5, 'floor_range': (1892, 1895)}
#                                 didn't broke: 1895 {'glasses': 5, 'floor_range': (1894, 1895)}
#                                     didn't broke: 1895 found
#                                     broke: 1894 found
#                                 broke: 1893 {'glasses': 4, 'floor_range': (1892, 1893)}
#                                     didn't broke: 1893 found
#                                     broke: 1892 found
#                             broke: 1890 {'glasses': 4, 'floor_range': (1888, 1891)}
#                                 didn't broke: 1891 {'glasses': 4, 'floor_range': (1890, 1891)}
#                                     didn't broke: 1891 found
#                                     broke: 1890 found
#                                 broke: 1889 {'glasses': 3, 'floor_range': (1888, 1889)}
#                                     didn't broke: 1889 found
#                                     broke: 1888 found
#                         broke: 1884 {'glasses': 4, 'floor_range': (1880, 1887)}
#                             didn't broke: 1886 {'glasses': 4, 'floor_range': (1884, 1887)}
#                                 didn't broke: 1887 {'glasses': 4, 'floor_range': (1886, 1887)}
#                                     didn't broke: 1887 found
#                                     broke: 1886 found
#                                 broke: 1885 {'glasses': 3, 'floor_range': (1884, 1885)}
#                                     didn't broke: 1885 found
#                                     broke: 1884 found
#                             broke: 1882 {'glasses': 3, 'floor_range': (1880, 1883)}
#                                 didn't broke: 1883 {'glasses': 3, 'floor_range': (1882, 1883)}
#                                     didn't broke: 1883 found
#                                     broke: 1882 found
#                                 broke: 1881 {'glasses': 2, 'floor_range': (1880, 1881)}
#                                     didn't broke: 1881 found
#                                     broke: 1880 found
#             broke: 1848 {'glasses': 6, 'floor_range': (1816, 1879)}
#                 didn't broke: 1864 {'glasses': 6, 'floor_range': (1848, 1879)}
#                     didn't broke: 1872 {'glasses': 6, 'floor_range': (1864, 1879)}
#                         didn't broke: 1876 {'glasses': 6, 'floor_range': (1872, 1879)}
#                             didn't broke: 1878 {'glasses': 6, 'floor_range': (1876, 1879)}
#                                 didn't broke: 1879 {'glasses': 6, 'floor_range': (1878, 1879)}
#                                     didn't broke: 1879 found
#                                     broke: 1878 found
#                                 broke: 1877 {'glasses': 5, 'floor_range': (1876, 1877)}
#                                     didn't broke: 1877 found
#                                     broke: 1876 found
#                             broke: 1874 {'glasses': 5, 'floor_range': (1872, 1875)}
#                                 didn't broke: 1875 {'glasses': 5, 'floor_range': (1874, 1875)}
#                                     didn't broke: 1875 found
#                                     broke: 1874 found
#                                 broke: 1873 {'glasses': 4, 'floor_range': (1872, 1873)}
#                                     didn't broke: 1873 found
#                                     broke: 1872 found
#                         broke: 1868 {'glasses': 5, 'floor_range': (1864, 1871)}
#                             didn't broke: 1870 {'glasses': 5, 'floor_range': (1868, 1871)}
#                                 didn't broke: 1871 {'glasses': 5, 'floor_range': (1870, 1871)}
#                                     didn't broke: 1871 found
#                                     broke: 1870 found
#                                 broke: 1869 {'glasses': 4, 'floor_range': (1868, 1869)}
#                                     didn't broke: 1869 found
#                                     broke: 1868 found
#                             broke: 1866 {'glasses': 4, 'floor_range': (1864, 1867)}
#                                 didn't broke: 1867 {'glasses': 4, 'floor_range': (1866, 1867)}
#                                     didn't broke: 1867 found
#                                     broke: 1866 found
#                                 broke: 1865 {'glasses': 3, 'floor_range': (1864, 1865)}
#                                     didn't broke: 1865 found
#                                     broke: 1864 found
#                     broke: 1856 {'glasses': 5, 'floor_range': (1848, 1863)}
#                         didn't broke: 1860 {'glasses': 5, 'floor_range': (1856, 1863)}
#                             didn't broke: 1862 {'glasses': 5, 'floor_range': (1860, 1863)}
#                                 didn't broke: 1863 {'glasses': 5, 'floor_range': (1862, 1863)}
#                                     didn't broke: 1863 found
#                                     broke: 1862 found
#                                 broke: 1861 {'glasses': 4, 'floor_range': (1860, 1861)}
#                                     didn't broke: 1861 found
#                                     broke: 1860 found
#                             broke: 1858 {'glasses': 4, 'floor_range': (1856, 1859)}
#                                 didn't broke: 1859 {'glasses': 4, 'floor_range': (1858, 1859)}
#                                     didn't broke: 1859 found
#                                     broke: 1858 found
#                                 broke: 1857 {'glasses': 3, 'floor_range': (1856, 1857)}
#                                     didn't broke: 1857 found
#                                     broke: 1856 found
#                         broke: 1852 {'glasses': 4, 'floor_range': (1848, 1855)}
#                             didn't broke: 1854 {'glasses': 4, 'floor_range': (1852, 1855)}
#                                 didn't broke: 1855 {'glasses': 4, 'floor_range': (1854, 1855)}
#                                     didn't broke: 1855 found
#                                     broke: 1854 found
#                                 broke: 1853 {'glasses': 3, 'floor_range': (1852, 1853)}
#                                     didn't broke: 1853 found
#                                     broke: 1852 found
#                             broke: 1850 {'glasses': 3, 'floor_range': (1848, 1851)}
#                                 didn't broke: 1851 {'glasses': 3, 'floor_range': (1850, 1851)}
#                                     didn't broke: 1851 found
#                                     broke: 1850 found
#                                 broke: 1849 {'glasses': 2, 'floor_range': (1848, 1849)}
#                                     didn't broke: 1849 found
#                                     broke: 1848 found
#                 broke: 1832 {'glasses': 5, 'floor_range': (1816, 1847)}
#                     didn't broke: 1840 {'glasses': 5, 'floor_range': (1832, 1847)}
#                         didn't broke: 1844 {'glasses': 5, 'floor_range': (1840, 1847)}
#                             didn't broke: 1846 {'glasses': 5, 'floor_range': (1844, 1847)}
#                                 didn't broke: 1847 {'glasses': 5, 'floor_range': (1846, 1847)}
#                                     didn't broke: 1847 found
#                                     broke: 1846 found
#                                 broke: 1845 {'glasses': 4, 'floor_range': (1844, 1845)}
#                                     didn't broke: 1845 found
#                                     broke: 1844 found
#                             broke: 1842 {'glasses': 4, 'floor_range': (1840, 1843)}
#                                 didn't broke: 1843 {'glasses': 4, 'floor_range': (1842, 1843)}
#                                     didn't broke: 1843 found
#                                     broke: 1842 found
#                                 broke: 1841 {'glasses': 3, 'floor_range': (1840, 1841)}
#                                     didn't broke: 1841 found
#                                     broke: 1840 found
#                         broke: 1836 {'glasses': 4, 'floor_range': (1832, 1839)}
#                             didn't broke: 1838 {'glasses': 4, 'floor_range': (1836, 1839)}
#                                 didn't broke: 1839 {'glasses': 4, 'floor_range': (1838, 1839)}
#                                     didn't broke: 1839 found
#                                     broke: 1838 found
#                                 broke: 1837 {'glasses': 3, 'floor_range': (1836, 1837)}
#                                     didn't broke: 1837 found
#                                     broke: 1836 found
#                             broke: 1834 {'glasses': 3, 'floor_range': (1832, 1835)}
#                                 didn't broke: 1835 {'glasses': 3, 'floor_range': (1834, 1835)}
#                                     didn't broke: 1835 found
#                                     broke: 1834 found
#                                 broke: 1833 {'glasses': 2, 'floor_range': (1832, 1833)}
#                                     didn't broke: 1833 found
#                                     broke: 1832 found
#                     broke: 1824 {'glasses': 4, 'floor_range': (1816, 1831)}
#                         didn't broke: 1828 {'glasses': 4, 'floor_range': (1824, 1831)}
#                             didn't broke: 1830 {'glasses': 4, 'floor_range': (1828, 1831)}
#                                 didn't broke: 1831 {'glasses': 4, 'floor_range': (1830, 1831)}
#                                     didn't broke: 1831 found
#                                     broke: 1830 found
#                                 broke: 1829 {'glasses': 3, 'floor_range': (1828, 1829)}
#                                     didn't broke: 1829 found
#                                     broke: 1828 found
#                             broke: 1826 {'glasses': 3, 'floor_range': (1824, 1827)}
#                                 didn't broke: 1827 {'glasses': 3, 'floor_range': (1826, 1827)}
#                                     didn't broke: 1827 found
#                                     broke: 1826 found
#                                 broke: 1825 {'glasses': 2, 'floor_range': (1824, 1825)}
#                                     didn't broke: 1825 found
#                                     broke: 1824 found
#                         broke: 1820 {'glasses': 3, 'floor_range': (1816, 1823)}
#                             didn't broke: 1822 {'glasses': 3, 'floor_range': (1820, 1823)}
#                                 didn't broke: 1823 {'glasses': 3, 'floor_range': (1822, 1823)}
#                                     didn't broke: 1823 found
#                                     broke: 1822 found
#                                 broke: 1821 {'glasses': 2, 'floor_range': (1820, 1821)}
#                                     didn't broke: 1821 found
#                                     broke: 1820 found
#                             broke: 1818 {'glasses': 2, 'floor_range': (1816, 1819)}
#                                 didn't broke: 1819 {'glasses': 2, 'floor_range': (1818, 1819)}
#                                     didn't broke: 1819 found
#                                     broke: 1818 found
#                                 broke: 1817 {'glasses': 1, 'floor_range': (1816, 1817)}
#                                     didn't broke: 1817 found
#                                     broke: 1816 found
#     broke: 848 {'glasses': 7, 'floor_range': (0, 1815)}
#         didn't broke: 1314 {'glasses': 7, 'floor_range': (848, 1815)}
#             didn't broke: 1561 {'glasses': 7, 'floor_range': (1314, 1815)}
#                 didn't broke: 1688 {'glasses': 7, 'floor_range': (1561, 1815)}
#                     didn't broke: 1752 {'glasses': 7, 'floor_range': (1688, 1815)}
#                         didn't broke: 1784 {'glasses': 7, 'floor_range': (1752, 1815)}
#                             didn't broke: 1800 {'glasses': 7, 'floor_range': (1784, 1815)}
#                                 didn't broke: 1808 {'glasses': 7, 'floor_range': (1800, 1815)}
#                                     didn't broke: 1812 {'glasses': 7, 'floor_range': (1808, 1815)}
#                                         didn't broke: 1814 {'glasses': 7, 'floor_range': (1812, 1815)}
#                                             didn't broke: 1815 {'glasses': 7, 'floor_range': (1814, 1815)}
#                                                 didn't broke: 1815 found
#                                                 broke: 1814 found
#                                             broke: 1813 {'glasses': 6, 'floor_range': (1812, 1813)}
#                                                 didn't broke: 1813 found
#                                                 broke: 1812 found
#                                         broke: 1810 {'glasses': 6, 'floor_range': (1808, 1811)}
#                                             didn't broke: 1811 {'glasses': 6, 'floor_range': (1810, 1811)}
#                                                 didn't broke: 1811 found
#                                                 broke: 1810 found
#                                             broke: 1809 {'glasses': 5, 'floor_range': (1808, 1809)}
#                                                 didn't broke: 1809 found
#                                                 broke: 1808 found
#                                     broke: 1804 {'glasses': 6, 'floor_range': (1800, 1807)}
#                                         didn't broke: 1806 {'glasses': 6, 'floor_range': (1804, 1807)}
#                                             didn't broke: 1807 {'glasses': 6, 'floor_range': (1806, 1807)}
#                                                 didn't broke: 1807 found
#                                                 broke: 1806 found
#                                             broke: 1805 {'glasses': 5, 'floor_range': (1804, 1805)}
#                                                 didn't broke: 1805 found
#                                                 broke: 1804 found
#                                         broke: 1802 {'glasses': 5, 'floor_range': (1800, 1803)}
#                                             didn't broke: 1803 {'glasses': 5, 'floor_range': (1802, 1803)}
#                                                 didn't broke: 1803 found
#                                                 broke: 1802 found
#                                             broke: 1801 {'glasses': 4, 'floor_range': (1800, 1801)}
#                                                 didn't broke: 1801 found
#                                                 broke: 1800 found
#                                 broke: 1792 {'glasses': 6, 'floor_range': (1784, 1799)}
#                                     didn't broke: 1796 {'glasses': 6, 'floor_range': (1792, 1799)}
#                                         didn't broke: 1798 {'glasses': 6, 'floor_range': (1796, 1799)}
#                                             didn't broke: 1799 {'glasses': 6, 'floor_range': (1798, 1799)}
#                                                 didn't broke: 1799 found
#                                                 broke: 1798 found
#                                             broke: 1797 {'glasses': 5, 'floor_range': (1796, 1797)}
#                                                 didn't broke: 1797 found
#                                                 broke: 1796 found
#                                         broke: 1794 {'glasses': 5, 'floor_range': (1792, 1795)}
#                                             didn't broke: 1795 {'glasses': 5, 'floor_range': (1794, 1795)}
#                                                 didn't broke: 1795 found
#                                                 broke: 1794 found
#                                             broke: 1793 {'glasses': 4, 'floor_range': (1792, 1793)}
#                                                 didn't broke: 1793 found
#                                                 broke: 1792 found
#                                     broke: 1788 {'glasses': 5, 'floor_range': (1784, 1791)}
#                                         didn't broke: 1790 {'glasses': 5, 'floor_range': (1788, 1791)}
#                                             didn't broke: 1791 {'glasses': 5, 'floor_range': (1790, 1791)}
#                                                 didn't broke: 1791 found
#                                                 broke: 1790 found
#                                             broke: 1789 {'glasses': 4, 'floor_range': (1788, 1789)}
#                                                 didn't broke: 1789 found
#                                                 broke: 1788 found
#                                         broke: 1786 {'glasses': 4, 'floor_range': (1784, 1787)}
#                                             didn't broke: 1787 {'glasses': 4, 'floor_range': (1786, 1787)}
#                                                 didn't broke: 1787 found
#                                                 broke: 1786 found
#                                             broke: 1785 {'glasses': 3, 'floor_range': (1784, 1785)}
#                                                 didn't broke: 1785 found
#                                                 broke: 1784 found
#                             broke: 1768 {'glasses': 6, 'floor_range': (1752, 1783)}
#                                 didn't broke: 1776 {'glasses': 6, 'floor_range': (1768, 1783)}
#                                     didn't broke: 1780 {'glasses': 6, 'floor_range': (1776, 1783)}
#                                         didn't broke: 1782 {'glasses': 6, 'floor_range': (1780, 1783)}
#                                             didn't broke: 1783 {'glasses': 6, 'floor_range': (1782, 1783)}
#                                                 didn't broke: 1783 found
#                                                 broke: 1782 found
#                                             broke: 1781 {'glasses': 5, 'floor_range': (1780, 1781)}
#                                                 didn't broke: 1781 found
#                                                 broke: 1780 found
#                                         broke: 1778 {'glasses': 5, 'floor_range': (1776, 1779)}
#                                             didn't broke: 1779 {'glasses': 5, 'floor_range': (1778, 1779)}
#                                                 didn't broke: 1779 found
#                                                 broke: 1778 found
#                                             broke: 1777 {'glasses': 4, 'floor_range': (1776, 1777)}
#                                                 didn't broke: 1777 found
#                                                 broke: 1776 found
#                                     broke: 1772 {'glasses': 5, 'floor_range': (1768, 1775)}
#                                         didn't broke: 1774 {'glasses': 5, 'floor_range': (1772, 1775)}
#                                             didn't broke: 1775 {'glasses': 5, 'floor_range': (1774, 1775)}
#                                                 didn't broke: 1775 found
#                                                 broke: 1774 found
#                                             broke: 1773 {'glasses': 4, 'floor_range': (1772, 1773)}
#                                                 didn't broke: 1773 found
#                                                 broke: 1772 found
#                                         broke: 1770 {'glasses': 4, 'floor_range': (1768, 1771)}
#                                             didn't broke: 1771 {'glasses': 4, 'floor_range': (1770, 1771)}
#                                                 didn't broke: 1771 found
#                                                 broke: 1770 found
#                                             broke: 1769 {'glasses': 3, 'floor_range': (1768, 1769)}
#                                                 didn't broke: 1769 found
#                                                 broke: 1768 found
#                                 broke: 1760 {'glasses': 5, 'floor_range': (1752, 1767)}
#                                     didn't broke: 1764 {'glasses': 5, 'floor_range': (1760, 1767)}
#                                         didn't broke: 1766 {'glasses': 5, 'floor_range': (1764, 1767)}
#                                             didn't broke: 1767 {'glasses': 5, 'floor_range': (1766, 1767)}
#                                                 didn't broke: 1767 found
#                                                 broke: 1766 found
#                                             broke: 1765 {'glasses': 4, 'floor_range': (1764, 1765)}
#                                                 didn't broke: 1765 found
#                                                 broke: 1764 found
#                                         broke: 1762 {'glasses': 4, 'floor_range': (1760, 1763)}
#                                             didn't broke: 1763 {'glasses': 4, 'floor_range': (1762, 1763)}
#                                                 didn't broke: 1763 found
#                                                 broke: 1762 found
#                                             broke: 1761 {'glasses': 3, 'floor_range': (1760, 1761)}
#                                                 didn't broke: 1761 found
#                                                 broke: 1760 found
#                                     broke: 1756 {'glasses': 4, 'floor_range': (1752, 1759)}
#                                         didn't broke: 1758 {'glasses': 4, 'floor_range': (1756, 1759)}
#                                             didn't broke: 1759 {'glasses': 4, 'floor_range': (1758, 1759)}
#                                                 didn't broke: 1759 found
#                                                 broke: 1758 found
#                                             broke: 1757 {'glasses': 3, 'floor_range': (1756, 1757)}
#                                                 didn't broke: 1757 found
#                                                 broke: 1756 found
#                                         broke: 1754 {'glasses': 3, 'floor_range': (1752, 1755)}
#                                             didn't broke: 1755 {'glasses': 3, 'floor_range': (1754, 1755)}
#                                                 didn't broke: 1755 found
#                                                 broke: 1754 found
#                                             broke: 1753 {'glasses': 2, 'floor_range': (1752, 1753)}
#                                                 didn't broke: 1753 found
#                                                 broke: 1752 found
#                         broke: 1720 {'glasses': 6, 'floor_range': (1688, 1751)}
#                             didn't broke: 1736 {'glasses': 6, 'floor_range': (1720, 1751)}
#                                 didn't broke: 1744 {'glasses': 6, 'floor_range': (1736, 1751)}
#                                     didn't broke: 1748 {'glasses': 6, 'floor_range': (1744, 1751)}
#                                         didn't broke: 1750 {'glasses': 6, 'floor_range': (1748, 1751)}
#                                             didn't broke: 1751 {'glasses': 6, 'floor_range': (1750, 1751)}
#                                                 didn't broke: 1751 found
#                                                 broke: 1750 found
#                                             broke: 1749 {'glasses': 5, 'floor_range': (1748, 1749)}
#                                                 didn't broke: 1749 found
#                                                 broke: 1748 found
#                                         broke: 1746 {'glasses': 5, 'floor_range': (1744, 1747)}
#                                             didn't broke: 1747 {'glasses': 5, 'floor_range': (1746, 1747)}
#                                                 didn't broke: 1747 found
#                                                 broke: 1746 found
#                                             broke: 1745 {'glasses': 4, 'floor_range': (1744, 1745)}
#                                                 didn't broke: 1745 found
#                                                 broke: 1744 found
#                                     broke: 1740 {'glasses': 5, 'floor_range': (1736, 1743)}
#                                         didn't broke: 1742 {'glasses': 5, 'floor_range': (1740, 1743)}
#                                             didn't broke: 1743 {'glasses': 5, 'floor_range': (1742, 1743)}
#                                                 didn't broke: 1743 found
#                                                 broke: 1742 found
#                                             broke: 1741 {'glasses': 4, 'floor_range': (1740, 1741)}
#                                                 didn't broke: 1741 found
#                                                 broke: 1740 found
#                                         broke: 1738 {'glasses': 4, 'floor_range': (1736, 1739)}
#                                             didn't broke: 1739 {'glasses': 4, 'floor_range': (1738, 1739)}
#                                                 didn't broke: 1739 found
#                                                 broke: 1738 found
#                                             broke: 1737 {'glasses': 3, 'floor_range': (1736, 1737)}
#                                                 didn't broke: 1737 found
#                                                 broke: 1736 found
#                                 broke: 1728 {'glasses': 5, 'floor_range': (1720, 1735)}
#                                     didn't broke: 1732 {'glasses': 5, 'floor_range': (1728, 1735)}
#                                         didn't broke: 1734 {'glasses': 5, 'floor_range': (1732, 1735)}
#                                             didn't broke: 1735 {'glasses': 5, 'floor_range': (1734, 1735)}
#                                                 didn't broke: 1735 found
#                                                 broke: 1734 found
#                                             broke: 1733 {'glasses': 4, 'floor_range': (1732, 1733)}
#                                                 didn't broke: 1733 found
#                                                 broke: 1732 found
#                                         broke: 1730 {'glasses': 4, 'floor_range': (1728, 1731)}
#                                             didn't broke: 1731 {'glasses': 4, 'floor_range': (1730, 1731)}
#                                                 didn't broke: 1731 found
#                                                 broke: 1730 found
#                                             broke: 1729 {'glasses': 3, 'floor_range': (1728, 1729)}
#                                                 didn't broke: 1729 found
#                                                 broke: 1728 found
#                                     broke: 1724 {'glasses': 4, 'floor_range': (1720, 1727)}
#                                         didn't broke: 1726 {'glasses': 4, 'floor_range': (1724, 1727)}
#                                             didn't broke: 1727 {'glasses': 4, 'floor_range': (1726, 1727)}
#                                                 didn't broke: 1727 found
#                                                 broke: 1726 found
#                                             broke: 1725 {'glasses': 3, 'floor_range': (1724, 1725)}
#                                                 didn't broke: 1725 found
#                                                 broke: 1724 found
#                                         broke: 1722 {'glasses': 3, 'floor_range': (1720, 1723)}
#                                             didn't broke: 1723 {'glasses': 3, 'floor_range': (1722, 1723)}
#                                                 didn't broke: 1723 found
#                                                 broke: 1722 found
#                                             broke: 1721 {'glasses': 2, 'floor_range': (1720, 1721)}
#                                                 didn't broke: 1721 found
#                                                 broke: 1720 found
#                             broke: 1704 {'glasses': 5, 'floor_range': (1688, 1719)}
#                                 didn't broke: 1712 {'glasses': 5, 'floor_range': (1704, 1719)}
#                                     didn't broke: 1716 {'glasses': 5, 'floor_range': (1712, 1719)}
#                                         didn't broke: 1718 {'glasses': 5, 'floor_range': (1716, 1719)}
#                                             didn't broke: 1719 {'glasses': 5, 'floor_range': (1718, 1719)}
#                                                 didn't broke: 1719 found
#                                                 broke: 1718 found
#                                             broke: 1717 {'glasses': 4, 'floor_range': (1716, 1717)}
#                                                 didn't broke: 1717 found
#                                                 broke: 1716 found
#                                         broke: 1714 {'glasses': 4, 'floor_range': (1712, 1715)}
#                                             didn't broke: 1715 {'glasses': 4, 'floor_range': (1714, 1715)}
#                                                 didn't broke: 1715 found
#                                                 broke: 1714 found
#                                             broke: 1713 {'glasses': 3, 'floor_range': (1712, 1713)}
#                                                 didn't broke: 1713 found
#                                                 broke: 1712 found
#                                     broke: 1708 {'glasses': 4, 'floor_range': (1704, 1711)}
#                                         didn't broke: 1710 {'glasses': 4, 'floor_range': (1708, 1711)}
#                                             didn't broke: 1711 {'glasses': 4, 'floor_range': (1710, 1711)}
#                                                 didn't broke: 1711 found
#                                                 broke: 1710 found
#                                             broke: 1709 {'glasses': 3, 'floor_range': (1708, 1709)}
#                                                 didn't broke: 1709 found
#                                                 broke: 1708 found
#                                         broke: 1706 {'glasses': 3, 'floor_range': (1704, 1707)}
#                                             didn't broke: 1707 {'glasses': 3, 'floor_range': (1706, 1707)}
#                                                 didn't broke: 1707 found
#                                                 broke: 1706 found
#                                             broke: 1705 {'glasses': 2, 'floor_range': (1704, 1705)}
#                                                 didn't broke: 1705 found
#                                                 broke: 1704 found
#                                 broke: 1696 {'glasses': 4, 'floor_range': (1688, 1703)}
#                                     didn't broke: 1700 {'glasses': 4, 'floor_range': (1696, 1703)}
#                                         didn't broke: 1702 {'glasses': 4, 'floor_range': (1700, 1703)}
#                                             didn't broke: 1703 {'glasses': 4, 'floor_range': (1702, 1703)}
#                                                 didn't broke: 1703 found
#                                                 broke: 1702 found
#                                             broke: 1701 {'glasses': 3, 'floor_range': (1700, 1701)}
#                                                 didn't broke: 1701 found
#                                                 broke: 1700 found
#                                         broke: 1698 {'glasses': 3, 'floor_range': (1696, 1699)}
#                                             didn't broke: 1699 {'glasses': 3, 'floor_range': (1698, 1699)}
#                                                 didn't broke: 1699 found
#                                                 broke: 1698 found
#                                             broke: 1697 {'glasses': 2, 'floor_range': (1696, 1697)}
#                                                 didn't broke: 1697 found
#                                                 broke: 1696 found
#                                     broke: 1692 {'glasses': 3, 'floor_range': (1688, 1695)}
#                                         didn't broke: 1694 {'glasses': 3, 'floor_range': (1692, 1695)}
#                                             didn't broke: 1695 {'glasses': 3, 'floor_range': (1694, 1695)}
#                                                 didn't broke: 1695 found
#                                                 broke: 1694 found
#                                             broke: 1693 {'glasses': 2, 'floor_range': (1692, 1693)}
#                                                 didn't broke: 1693 found
#                                                 broke: 1692 found
#                                         broke: 1690 {'glasses': 2, 'floor_range': (1688, 1691)}
#                                             didn't broke: 1691 {'glasses': 2, 'floor_range': (1690, 1691)}
#                                                 didn't broke: 1691 found
# ...
#                                                 didn't broke: 105 found
#                                                 broke: 104 found
#                                             broke: 103 {'glasses': 2, 'floor_range': (102, 103)}
#                                                 didn't broke: 103 found
#                                                 broke: 102 found
#                                         broke: 100 {'glasses': 2, 'floor_range': (98, 101)}
#                                             didn't broke: 101 {'glasses': 2, 'floor_range': (100, 101)}
#                                                 didn't broke: 101 found
#                                                 broke: 100 found
#                                             broke: 99 {'glasses': 1, 'floor_range': (98, 99)}
#                                                 didn't broke: 99 found
#                                                 broke: 98 found
#                                     broke: 94 {'glasses': 2, 'floor_range': (91, 97)}
#                                         didn't broke: 96 {'glasses': 2, 'floor_range': (94, 97)}
#                                             didn't broke: 97 {'glasses': 2, 'floor_range': (96, 97)}
#                                                 didn't broke: 97 found
#                                                 broke: 96 found
#                                             broke: 95 {'glasses': 1, 'floor_range': (94, 95)}
#                                                 didn't broke: 95 found
#                                                 broke: 94 found
#                                         broke: 92 {'glasses': 1, 'floor_range': (91, 93)}
#                                             didn't broke: 93 {'glasses': 1, 'floor_range': (92, 93)}
#                                                 didn't broke: 93 found
#                                                 broke: 92 found
#                                             broke: 91 found
#                                 broke: 84 {'glasses': 2, 'floor_range': (80, 90)}
#                                     didn't broke: 87 {'glasses': 2, 'floor_range': (84, 90)}
#                                         didn't broke: 89 {'glasses': 2, 'floor_range': (87, 90)}
#                                             didn't broke: 90 {'glasses': 2, 'floor_range': (89, 90)}
#                                                 didn't broke: 90 found
#                                                 broke: 89 found
#                                             broke: 88 {'glasses': 1, 'floor_range': (87, 88)}
#                                                 didn't broke: 88 found
#                                                 broke: 87 found
#                                         broke: 85 {'glasses': 1, 'floor_range': (84, 86)}
#                                             didn't broke: 86 {'glasses': 1, 'floor_range': (85, 86)}
#                                                 didn't broke: 86 found
#                                                 broke: 85 found
#                                             broke: 84 found
#                                     broke: 81 {'glasses': 1, 'floor_range': (80, 83)}
#                                         didn't broke: 82 {'glasses': 1, 'floor_range': (81, 83)}
#                                             didn't broke: 83 {'glasses': 1, 'floor_range': (82, 83)}
#                                                 didn't broke: 83 found
#                                                 broke: 82 found
#                                             broke: 81 found
#                                         broke: 80 found
#                             broke: 69 {'glasses': 2, 'floor_range': (64, 79)}
#                                 didn't broke: 73 {'glasses': 2, 'floor_range': (69, 79)}
#                                     didn't broke: 76 {'glasses': 2, 'floor_range': (73, 79)}
#                                         didn't broke: 78 {'glasses': 2, 'floor_range': (76, 79)}
#                                             didn't broke: 79 {'glasses': 2, 'floor_range': (78, 79)}
#                                                 didn't broke: 79 found
#                                                 broke: 78 found
#                                             broke: 77 {'glasses': 1, 'floor_range': (76, 77)}
#                                                 didn't broke: 77 found
#                                                 broke: 76 found
#                                         broke: 74 {'glasses': 1, 'floor_range': (73, 75)}
#                                             didn't broke: 75 {'glasses': 1, 'floor_range': (74, 75)}
#                                                 didn't broke: 75 found
#                                                 broke: 74 found
#                                             broke: 73 found
#                                     broke: 70 {'glasses': 1, 'floor_range': (69, 72)}
#                                         didn't broke: 71 {'glasses': 1, 'floor_range': (70, 72)}
#                                             didn't broke: 72 {'glasses': 1, 'floor_range': (71, 72)}
#                                                 didn't broke: 72 found
#                                                 broke: 71 found
#                                             broke: 70 found
#                                         broke: 69 found
#                                 broke: 65 {'glasses': 1, 'floor_range': (64, 68)}
#                                     didn't broke: 66 {'glasses': 1, 'floor_range': (65, 68)}
#                                         didn't broke: 67 {'glasses': 1, 'floor_range': (66, 68)}
#                                             didn't broke: 68 {'glasses': 1, 'floor_range': (67, 68)}
#                                                 didn't broke: 68 found
#                                                 broke: 67 found
#                                             broke: 66 found
#                                         broke: 65 found
#                                     broke: 64 found
#                     broke: 22 {'glasses': 3, 'floor_range': (0, 63)}
#                         didn't broke: 38 {'glasses': 3, 'floor_range': (22, 63)}
#                             didn't broke: 49 {'glasses': 3, 'floor_range': (38, 63)}
#                                 didn't broke: 56 {'glasses': 3, 'floor_range': (49, 63)}
#                                     didn't broke: 60 {'glasses': 3, 'floor_range': (56, 63)}
#                                         didn't broke: 62 {'glasses': 3, 'floor_range': (60, 63)}
#                                             didn't broke: 63 {'glasses': 3, 'floor_range': (62, 63)}
#                                                 didn't broke: 63 found
#                                                 broke: 62 found
#                                             broke: 61 {'glasses': 2, 'floor_range': (60, 61)}
#                                                 didn't broke: 61 found
#                                                 broke: 60 found
#                                         broke: 58 {'glasses': 2, 'floor_range': (56, 59)}
#                                             didn't broke: 59 {'glasses': 2, 'floor_range': (58, 59)}
#                                                 didn't broke: 59 found
#                                                 broke: 58 found
#                                             broke: 57 {'glasses': 1, 'floor_range': (56, 57)}
#                                                 didn't broke: 57 found
#                                                 broke: 56 found
#                                     broke: 52 {'glasses': 2, 'floor_range': (49, 55)}
#                                         didn't broke: 54 {'glasses': 2, 'floor_range': (52, 55)}
#                                             didn't broke: 55 {'glasses': 2, 'floor_range': (54, 55)}
#                                                 didn't broke: 55 found
#                                                 broke: 54 found
#                                             broke: 53 {'glasses': 1, 'floor_range': (52, 53)}
#                                                 didn't broke: 53 found
#                                                 broke: 52 found
#                                         broke: 50 {'glasses': 1, 'floor_range': (49, 51)}
#                                             didn't broke: 51 {'glasses': 1, 'floor_range': (50, 51)}
#                                                 didn't broke: 51 found
#                                                 broke: 50 found
#                                             broke: 49 found
#                                 broke: 42 {'glasses': 2, 'floor_range': (38, 48)}
#                                     didn't broke: 45 {'glasses': 2, 'floor_range': (42, 48)}
#                                         didn't broke: 47 {'glasses': 2, 'floor_range': (45, 48)}
#                                             didn't broke: 48 {'glasses': 2, 'floor_range': (47, 48)}
#                                                 didn't broke: 48 found
#                                                 broke: 47 found
#                                             broke: 46 {'glasses': 1, 'floor_range': (45, 46)}
#                                                 didn't broke: 46 found
#                                                 broke: 45 found
#                                         broke: 43 {'glasses': 1, 'floor_range': (42, 44)}
#                                             didn't broke: 44 {'glasses': 1, 'floor_range': (43, 44)}
#                                                 didn't broke: 44 found
#                                                 broke: 43 found
#                                             broke: 42 found
#                                     broke: 39 {'glasses': 1, 'floor_range': (38, 41)}
#                                         didn't broke: 40 {'glasses': 1, 'floor_range': (39, 41)}
#                                             didn't broke: 41 {'glasses': 1, 'floor_range': (40, 41)}
#                                                 didn't broke: 41 found
#                                                 broke: 40 found
#                                             broke: 39 found
#                                         broke: 38 found
#                             broke: 27 {'glasses': 2, 'floor_range': (22, 37)}
#                                 didn't broke: 31 {'glasses': 2, 'floor_range': (27, 37)}
#                                     didn't broke: 34 {'glasses': 2, 'floor_range': (31, 37)}
#                                         didn't broke: 36 {'glasses': 2, 'floor_range': (34, 37)}
#                                             didn't broke: 37 {'glasses': 2, 'floor_range': (36, 37)}
#                                                 didn't broke: 37 found
#                                                 broke: 36 found
#                                             broke: 35 {'glasses': 1, 'floor_range': (34, 35)}
#                                                 didn't broke: 35 found
#                                                 broke: 34 found
#                                         broke: 32 {'glasses': 1, 'floor_range': (31, 33)}
#                                             didn't broke: 33 {'glasses': 1, 'floor_range': (32, 33)}
#                                                 didn't broke: 33 found
#                                                 broke: 32 found
#                                             broke: 31 found
#                                     broke: 28 {'glasses': 1, 'floor_range': (27, 30)}
#                                         didn't broke: 29 {'glasses': 1, 'floor_range': (28, 30)}
#                                             didn't broke: 30 {'glasses': 1, 'floor_range': (29, 30)}
#                                                 didn't broke: 30 found
#                                                 broke: 29 found
#                                             broke: 28 found
#                                         broke: 27 found
#                                 broke: 23 {'glasses': 1, 'floor_range': (22, 26)}
#                                     didn't broke: 24 {'glasses': 1, 'floor_range': (23, 26)}
#                                         didn't broke: 25 {'glasses': 1, 'floor_range': (24, 26)}
#                                             didn't broke: 26 {'glasses': 1, 'floor_range': (25, 26)}
#                                                 didn't broke: 26 found
#                                                 broke: 25 found
#                                             broke: 24 found
#                                         broke: 23 found
#                                     broke: 22 found
#                         broke: 6 {'glasses': 2, 'floor_range': (0, 21)}
#                             didn't broke: 11 {'glasses': 2, 'floor_range': (6, 21)}
#                                 didn't broke: 15 {'glasses': 2, 'floor_range': (11, 21)}
#                                     didn't broke: 18 {'glasses': 2, 'floor_range': (15, 21)}
#                                         didn't broke: 20 {'glasses': 2, 'floor_range': (18, 21)}
#                                             didn't broke: 21 {'glasses': 2, 'floor_range': (20, 21)}
#                                                 didn't broke: 21 found
#                                                 broke: 20 found
#                                             broke: 19 {'glasses': 1, 'floor_range': (18, 19)}
#                                                 didn't broke: 19 found
#                                                 broke: 18 found
#                                         broke: 16 {'glasses': 1, 'floor_range': (15, 17)}
#                                             didn't broke: 17 {'glasses': 1, 'floor_range': (16, 17)}
#                                                 didn't broke: 17 found
#                                                 broke: 16 found
#                                             broke: 15 found
#                                     broke: 12 {'glasses': 1, 'floor_range': (11, 14)}
#                                         didn't broke: 13 {'glasses': 1, 'floor_range': (12, 14)}
#                                             didn't broke: 14 {'glasses': 1, 'floor_range': (13, 14)}
#                                                 didn't broke: 14 found
#                                                 broke: 13 found
#                                             broke: 12 found
#                                         broke: 11 found
#                                 broke: 7 {'glasses': 1, 'floor_range': (6, 10)}
#                                     didn't broke: 8 {'glasses': 1, 'floor_range': (7, 10)}
#                                         didn't broke: 9 {'glasses': 1, 'floor_range': (8, 10)}
#                                             didn't broke: 10 {'glasses': 1, 'floor_range': (9, 10)}
#                                                 didn't broke: 10 found
#                                                 broke: 9 found
#                                             broke: 8 found
#                                         broke: 7 found
#                                     broke: 6 found
#                             broke: 1 {'glasses': 1, 'floor_range': (0, 5)}
#                                 didn't broke: 2 {'glasses': 1, 'floor_range': (1, 5)}
#                                     didn't broke: 3 {'glasses': 1, 'floor_range': (2, 5)}
#                                         didn't broke: 4 {'glasses': 1, 'floor_range': (3, 5)}
#                                             didn't broke: 5 {'glasses': 1, 'floor_range': (4, 5)}
#                                                 didn't broke: 5 found
#                                                 broke: 4 found
#                                             broke: 3 found
#                                         broke: 2 found
#                                     broke: 1 found
#                                 broke: 0 found
